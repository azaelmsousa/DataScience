# %%
%lsmagic
# Out:
# Available magics:
# %auth  %display  %endpoint  %format  %graph  %header  %lang  %log  %lsmagics  %outfile  %prefix  %qparam  %show
#
# %auth (basic|digest|none) <username> <passwd> : send HTTP authentication
# %display raw | table [withtypes] | diagram [svg|png] [withliterals] : set display format
# %endpoint <url> : set SPARQL endpoint. **REQUIRED**
# %format JSON | N3 | XML | any | default : set requested result format
# %graph <uri> : set default graph for the queries
# %header <string> | OFF : add a persistent header line before the query, or delete all defined headers
# %lang <lang> [...] | default | all : language(s) preferred for labels
# %log critical | error | warning | info | debug : set logging level
# %lsmagics  : list all magics
# %outfile <filename> | NONE : save raw output to a file (use "%d" in name to add cell number, "NONE" to cancel saving)
# %prefix <name> [<uri>] : set (or delete) a persistent URI prefix for all queries
# ...

# %% [markdown]
# ## Testando SPARQL com o exemplo do Prof.
# Este exemplo serve apenas para checar se as instalações do SPARQL foram realizadas com sucesso.

# %%
%endpoint http://id.nlm.nih.gov/mesh/sparql
%display table
%show all
# Out:
# Endpoint set to: http://id.nlm.nih.gov/mesh/sparql
# Display: table
# Result maximum size: unlimited

# %%
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>

SELECT ?entity
FROM <http://id.nlm.nih.gov/mesh>
WHERE {
    ?entity rdfs:label "Myocardial Infarction"@en
}
# Out:
# <div class="krn-spql"><table><tr class=hdr><th>entity</th></tr><tr class=odd><td class=val><a href="http://id.nlm.nih.gov/mesh/D009203" target="_other">http://id.nlm.nih.gov/mesh/D009203</a></td></tr><tr class=even><td class=val><a href="http://id.nlm.nih.gov/mesh/M0014340" target="_other">http://id.nlm.nih.gov/mesh/M0014340</a></td></tr></table><div class="tinfo">Total: 2, Shown: 2</div></div>

# %% [markdown]
# Está funcionando, então acredito que a instalação do SPARQL esteja ok.

# %% [markdown]
# ## SPARQL para a Ontologia IDODEN

# %%
%endpoint http://sparql.bioontology.org/sparql
%display table
%show all
%format any
%qparam apikey 1ed557d6-a913-44c7-8097-10fedbf1b72d
# Out:
# Endpoint set to: http://sparql.bioontology.org/sparql
# Display: table
# Result maximum size: unlimited
# Return format: ANY
# Param set: apikey = 1ed557d6-a913-44c7-8097-10fedbf1b72d

# %% [markdown]
# ### Testando se o endpoint está funcionando corretamente

# %%
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX snomed-term: <http://purl.bioontology.org/ontology/SNOMEDCT/>
PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
SELECT DISTINCT ?x ?label
FROM <http://bioportal.bioontology.org/ontologies/SNOMEDCT>
WHERE
{
    ?x rdfs:subClassOf snomed-term:363664003 .
    ?x skos:prefLabel  ?label.
}
# Out:
# <div class="krn-spql"><table><tr class=hdr><th>x</th>
# <th>label</th></tr><tr class=odd><td class=val><a href="http://purl.bioontology.org/ontology/SNOMEDCT/164075007" target="_other">http://purl.bioontology.org/ontology/SNOMEDCT/164075007</a></td>
# <td class=val>O/E-nystagmus-labyrinth-irreg.</td></tr><tr class=even><td class=val><a href="http://purl.bioontology.org/ontology/SNOMEDCT/141273001" target="_other">http://purl.bioontology.org/ontology/SNOMEDCT/141273001</a></td>
# <td class=val>O/E-nystagmus-labyrinth-irreg.</td></tr><tr class=odd><td class=val><a href="http://purl.bioontology.org/ontology/SNOMEDCT/15794003" target="_other">http://purl.bioontology.org/ontology/SNOMEDCT/15794003</a></td>
# <td class=val>Drug gel, 0,05%</td></tr><tr class=even><td class=val><a href="http://purl.bioontology.org/ontology/SNOMEDCT/201794001" target="_other">http://purl.bioontology.org/ontology/SNOMEDCT/201794001</a></td>
# ...

# %% [markdown]
# ### Iniciando testes com a Ontologia IDODEN

# %%
SELECT DISTINCT ?x ?concept
FROM <http://bioportal.bioontology.org/ontologies/IDODEN>
WHERE {
    ?x a ?concept
}
# Out:
# <div class="krn-spql"><table><tr class=hdr><th>x</th>
# <th>concept</th></tr><tr class=odd><td class=val><a href="http://bioportal.bioontology.org/.well-known/genid/33a788b7-3805-4d08-ac1b-7a77008c8926/9ca20100000080" target="_other">http://bioportal.bioontology.org/.well-known/genid/33a788b7-3805-4d08-ac1b-7a77008c8926/9ca20100000080</a></td>
# <td class=val><a href="http://www.w3.org/2002/07/owl#Restriction" target="_other">http://www.w3.org/2002/07/owl#Restriction</a></td></tr><tr class=even><td class=val><a href="http://bioportal.bioontology.org/.well-known/genid/33a788b7-3805-4d08-ac1b-7a77008c8926/9ca20100000081" target="_other">http://bioportal.bioontology.org/.well-known/genid/33a788b7-3805-4d08-ac1b-7a77008c8926/9ca20100000081</a></td>
# ...

# %%
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX idoden: <http://purl.bioontology.org/ontology/IDODEN> 

SELECT DISTINCT ?x
FROM <http://bioportal.bioontology.org/ontologies/IDODEN>
WHERE {
    <http://anobase.vectorbase.org/idoden/idoden.owl#IDODEN_0000237> rdfs:label ?x
}
# Out:
# <div class="krn-spql"><table><tr class=hdr><th>x</th></tr><tr class=odd><td class=val>vaccination against dengue</td></tr></table><div class="tinfo">Total: 1, Shown: 1</div></div>

# %%
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX owl: <http://www.w3.org/2002/07/owl#>
PREFIX idoTerm: <http://purl.bioontology.org/ontology/IDODEN/>
PREFIX skos: <http://www.w3.org/2004/02/skos/core#>

SELECT ?instance ?label
FROM <http://bioportal.bioontology.org/ontologies/IDODEN> 
WHERE {
    ?instance rdfs:label ?label .
    ?instance rdfs:subClassOf <http://anobase.vectorbase.org/idoden/idoden.owl#IDODEN_0000237>
}
# Out:
# <div class="krn-spql"><table><tr class=hdr><th>instance</th>
# <th>label</th></tr><tr class=odd><td class=val><a href="http://anobase.vectorbase.org/idoden/idoden.owl#IDODEN_0000242" target="_other">http://anobase.vectorbase.org/idoden/idoden.owl#IDODEN_0000242</a></td>
# <td class=val>vaccination against serotype 4 dengue</td></tr><tr class=even><td class=val><a href="http://anobase.vectorbase.org/idoden/idoden.owl#IDODEN_0000241" target="_other">http://anobase.vectorbase.org/idoden/idoden.owl#IDODEN_0000241</a></td>
# <td class=val>vaccination against serotype 3 dengue</td></tr><tr class=odd><td class=val><a href="http://anobase.vectorbase.org/idoden/idoden.owl#IDODEN_0000240" target="_other">http://anobase.vectorbase.org/idoden/idoden.owl#IDODEN_0000240</a></td>
# ...

# %%
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX owl: <http://www.w3.org/2002/07/owl#>
PREFIX idoden: <https://github.com/azaelmsousa/DataScience/blob/master/Ontology/idoden.obo>
PREFIX idoTerm: <http://purl.bioontology.org/ontology/IDODEN/>
PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
PREFIX idomal: <http://purl.obolibrary.org/obo/idomal>

SELECT ?instance ?label 
FROM <http://bioportal.bioontology.org/ontologies/IDODEN> 
WHERE {
     ?s rdf:type ?o .
	FILTER ( ?s = <http://purl.obolibrary.org/obo/idomal#agent_in> )
}
# Out:
# <div class="krn-spql"><table><tr class=hdr><th>instance</th>
# <th>label</th></tr></table><div class="tinfo">Total: 0, Shown: 0</div></div>

# %%
SELECT DISTINCT ?g ?p ?o WHERE {
	GRAPH ?g {
		<http://purl.obolibrary.org/obo/IDOMAL_0002303> ?p ?o
	}
}
# Out:
# <div class="krn-spql"><table><tr class=hdr><th>g</th>
# <th>p</th>
# <th>o</th></tr><tr class=odd><td class=val><a href="http://bioportal.bioontology.org/ontologies/IDOMAL" target="_other">http://bioportal.bioontology.org/ontologies/IDOMAL</a></td>
# <td class=val><a href="http://purl.obolibrary.org/obo/def" target="_other">http://purl.obolibrary.org/obo/def</a></td>
# <td class=val>Female mosquitoes respond to host odour (CO2 emission, water vapour, volatiles molecules).</td></tr><tr class=even><td class=val><a href="http://bioportal.bioontology.org/ontologies/IDOMAL" target="_other">http://bioportal.bioontology.org/ontologies/IDOMAL</a></td>
# <td class=val><a href="http://www.w3.org/2000/01/rdf-schema#subClassOf" target="_other">http://www.w3.org/2000/01/rdf-schema#subClassOf</a></td>
# ...

# %%
SELECT DISTINCT ?g ?p ?o WHERE {
	GRAPH ?g {
		<http://anobase.vectorbase.org/idoden/idoden.owl#IDODEN_0000214> ?p ?o
	}
}
# Out:
# <div class="krn-spql"><table><tr class=hdr><th>g</th>
# <th>p</th>
# <th>o</th></tr><tr class=odd><td class=val><a href="http://bioportal.bioontology.org/ontologies/IDODEN" target="_other">http://bioportal.bioontology.org/ontologies/IDODEN</a></td>
# <td class=val><a href="http://purl.obolibrary.org/obo/IAO_0000115" target="_other">http://purl.obolibrary.org/obo/IAO_0000115</a></td>
# <td class=val>The quality of forms of dengue fever that are different from the epidemiological point of view.</td></tr><tr class=even><td class=val><a href="http://bioportal.bioontology.org/ontologies/IDODEN" target="_other">http://bioportal.bioontology.org/ontologies/IDODEN</a></td>
# <td class=val><a href="http://purl.obolibrary.org/obo/IAO_0000119" target="_other">http://purl.obolibrary.org/obo/IAO_0000119</a></td>
# ...

# %%
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>

SELECT ?instance ?label
FROM <http://bioportal.bioontology.org/ontologies/IDODEN> 
WHERE {
    ?instance rdfs:label ?label .
    ?instance rdfs:subClassOf <http://anobase.vectorbase.org/idoden/idoden.owl#IDODEN_0000214>
}
# Out:
# <div class="krn-spql"><table><tr class=hdr><th>instance</th>
# <th>label</th></tr><tr class=odd><td class=val><a href="http://anobase.vectorbase.org/idoden/idoden.owl#IDODEN_0000277" target="_other">http://anobase.vectorbase.org/idoden/idoden.owl#IDODEN_0000277</a></td>
# <td class=val>introduced dengue fever</td></tr><tr class=even><td class=val><a href="http://anobase.vectorbase.org/idoden/idoden.owl#IDODEN_0000282" target="_other">http://anobase.vectorbase.org/idoden/idoden.owl#IDODEN_0000282</a></td>
# <td class=val>war and conflict dengue fever</td></tr><tr class=odd><td class=val><a href="http://anobase.vectorbase.org/idoden/idoden.owl#IDODEN_0000278" target="_other">http://anobase.vectorbase.org/idoden/idoden.owl#IDODEN_0000278</a></td>
# <td class=val>sporadic dengue fever</td></tr><tr class=even><td class=val><a href="http://anobase.vectorbase.org/idoden/idoden.owl#IDODEN_0000269" target="_other">http://anobase.vectorbase.org/idoden/idoden.owl#IDODEN_0000269</a></td>
# ...

# %%
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>

SELECT ?instance ?label
FROM <http://bioportal.bioontology.org/ontologies/IDODEN> 
WHERE {
    ?instance rdfs:label ?label .
    ?instance rdfs:subClassOf <http://anobase.vectorbase.org/idoden/idoden.owl#IDODEN_0000229>
}
# Out:
# <div class="krn-spql"><table><tr class=hdr><th>instance</th>
# <th>label</th></tr><tr class=odd><td class=val><a href="http://anobase.vectorbase.org/idoden/idoden.owl#IDODEN_0003640" target="_other">http://anobase.vectorbase.org/idoden/idoden.owl#IDODEN_0003640</a></td>
# <td class=val>Aedes polynesiensis vector population</td></tr><tr class=even><td class=val><a href="http://anobase.vectorbase.org/idoden/idoden.owl#IDODEN_0003638" target="_other">http://anobase.vectorbase.org/idoden/idoden.owl#IDODEN_0003638</a></td>
# <td class=val>Aedes aegypti vector population</td></tr><tr class=odd><td class=val><a href="http://anobase.vectorbase.org/idoden/idoden.owl#IDODEN_0003639" target="_other">http://anobase.vectorbase.org/idoden/idoden.owl#IDODEN_0003639</a></td>
# ...

# %%
SELECT DISTINCT ?g ?p ?o WHERE {
	GRAPH ?g {
		<http://anobase.vectorbase.org/idoden/idoden.owl#IDODEN_0000283> ?p ?o
	}
}
# Out:
# <div class="krn-spql"><table><tr class=hdr><th>g</th>
# <th>p</th>
# <th>o</th></tr><tr class=odd><td class=val><a href="http://bioportal.bioontology.org/ontologies/IDODEN" target="_other">http://bioportal.bioontology.org/ontologies/IDODEN</a></td>
# <td class=val><a href="http://purl.obolibrary.org/obo/IAO_0000115" target="_other">http://purl.obolibrary.org/obo/IAO_0000115</a></td>
# <td class=val>A commercial product that provides all necessary components to perform an immunological test for the rapid diagnosis of dengue.</td></tr><tr class=even><td class=val><a href="http://bioportal.bioontology.org/ontologies/IDODEN" target="_other">http://bioportal.bioontology.org/ontologies/IDODEN</a></td>
# <td class=val><a href="http://purl.obolibrary.org/obo/IAO_0000119" target="_other">http://purl.obolibrary.org/obo/IAO_0000119</a></td>
# ...

# %%
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>

SELECT ?instance ?label ?definition 
FROM <http://bioportal.bioontology.org/ontologies/IDODEN> 
WHERE {
    ?instance rdfs:label ?label .
    ?instance rdfs:subClassOf <http://anobase.vectorbase.org/idoden/idoden.owl#IDODEN_0000283> .
    ?instance <http://purl.obolibrary.org/obo/IAO_0000115> ?definition 
}
# Out:
# <div class="krn-spql"><table><tr class=hdr><th>instance</th>
# <th>label</th>
# <th>definition</th></tr><tr class=odd><td class=val><a href="http://anobase.vectorbase.org/idoden/idoden.owl#IDODEN_0000286" target="_other">http://anobase.vectorbase.org/idoden/idoden.owl#IDODEN_0000286</a></td>
# <td class=val>Rapid Dengue Test (Dengue NS1 AG)</td>
# <td class=val>A commercial RDT from SD Inc.</td></tr><tr class=even><td class=val><a href="http://anobase.vectorbase.org/idoden/idoden.owl#IDODEN_0000291" target="_other">http://anobase.vectorbase.org/idoden/idoden.owl#IDODEN_0000291</a></td>
# <td class=val>Rapid Dengue Test Kit (AccuBioTech)</td>
# <td class=val>A commercial RDT from AccuBioTech Co., Ltd.</td></tr><tr class=odd><td class=val><a href="http://anobase.vectorbase.org/idoden/idoden.owl#IDODEN_0000292" target="_other">http://anobase.vectorbase.org/idoden/idoden.owl#IDODEN_0000292</a></td>
# <td class=val>One Step Dengue Test Kit (Lonsino)</td>
# ...

# %%
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>

SELECT ?x ?y
FROM <http://bioportal.bioontology.org/ontologies/IDODEN> 
WHERE {
#     <http://purl.obolibrary.org/obo/NCBITaxon_7159> <http://purl.obolibrary.org/obo/idomal#agent_in> ?x
    <http://purl.obolibrary.org/obo/NCBITaxon_7159> ?x ?y
}

# %%
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>

SELECT ?instance ?label ?firstSubClass
FROM <http://bioportal.bioontology.org/ontologies/IDODEN> 
WHERE {
    ?instance rdfs:label ?label .
    ?instance rdfs:subClassOf ?firstSubClass .
    ?firstSubClass rdfs:subClassOf <http://anobase.vectorbase.org/idoden/idoden.owl#IDODEN_0000002>
}
LIMIT 10
